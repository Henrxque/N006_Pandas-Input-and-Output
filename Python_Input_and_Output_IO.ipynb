# %% [markdown]
# <a href="https://colab.research.google.com/github/Henrxque/Pandas-Input-and-Output-/blob/main/Python_Input_and_Output_IO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importando os Dados

# %%
import pandas as pd

# %%
#para ler JSON
nomes_f = pd.read_json('https://guilhermeonrails.github.io/nomes_ibge/nomes-f.json')
nomes_f
# Out:
#           nome  regiao      freq  rank sexo
# 0        MARIA       0  11694738     1    F
# 1          ANA       0   3079729     2    F
# 2    FRANCISCA       0    721637     3    F
# 3      ANTONIA       0    588783     4    F
# 4      ADRIANA       0    565621     5    F
# ..         ...     ...       ...   ...  ...
# 195     ROSANE       0     82203   196    F
# 196    IVONETE       0     81878   197    F
# 197    LUCIANE       0     81230   198    F
# 198    ISADORA       0     81100   199    F
# 199      NILZA       0     80128   200    F
#
# [200 rows x 5 columns]

# %%
nomes_m = pd.read_json('https://guilhermeonrails.github.io/nomes_ibge/nomes-m.json')
nomes_m
# Out:
#           nome  regiao     freq  rank sexo
# 0         JOSE       0  5732508     1    M
# 1         JOAO       0  2971935     2    M
# 2      ANTONIO       0  2567494     3    M
# 3    FRANCISCO       0  1765197     4    M
# 4       CARLOS       0  1483121     5    M
# ..         ...     ...      ...   ...  ...
# 195     WALTER       0    67207   196    M
# 196    ARLINDO       0    66669   197    M
# 197    MICHAEL       0    65736   198    M
# 198     ALVARO       0    65444   199    M
# 199    GEOVANE       0    65435   200    M
#
# [200 rows x 5 columns]

# %%
#sortear nome
nomes_f.sample(5)
# Out:
#          nome  regiao    freq  rank sexo
# 156    YASMIN       0  103787   157    F
# 45    ANDREIA       0  290970    46    F
# 189     DALVA       0   83485   190    F
# 193  LUCILENE       0   82838   194    F
# 61     BIANCA       0  232855    62    F

# %%
#quantos nomes nós temos em cada um dos arquivos
print('Quantidade de nomes: '+ str(len(nomes_f) + len(nomes_m)))
# Out:
# Quantidade de nomes: 400

# %%
#unificar as listas
frames = [nomes_f, nomes_m]
frames
# Out:
# [          nome  regiao      freq  rank sexo
#  0        MARIA       0  11694738     1    F
#  1          ANA       0   3079729     2    F
#  2    FRANCISCA       0    721637     3    F
#  3      ANTONIA       0    588783     4    F
#  4      ADRIANA       0    565621     5    F
#  ..         ...     ...       ...   ...  ...
#  195     ROSANE       0     82203   196    F
#  196    IVONETE       0     81878   197    F
#  197    LUCIANE       0     81230   198    F
#  198    ISADORA       0     81100   199    F
#  199      NILZA       0     80128   200    F
#
#  [200 rows x 5 columns],           nome  regiao     freq  rank sexo
#  0         JOSE       0  5732508     1    M
#  1         JOAO       0  2971935     2    M
#  2      ANTONIO       0  2567494     3    M
#  3    FRANCISCO       0  1765197     4    M
#  4       CARLOS       0  1483121     5    M
#  ..         ...     ...      ...   ...  ...
#  195     WALTER       0    67207   196    M
# ...

# %%
#criei uma lista acima juntando os nomes_f e nomes_m, em seguida concatenei a variável frames que armazenou essa lista. 
#O campo que concatenei foi apenas o campo ['nome']
#to frame eu transformo a lista em um novo Dataframe
nomes = pd.concat(frames)['nome'].to_frame() 
nomes.sample(5)
# Out:
#         nome
# 46   FABIANA
# 159    SELMA
# 3    ANTONIA
# 97   BARBARA
# 64    ROBSON

# %% [markdown]
# ## Como incluir IDs (Randomizar)

# %%
import numpy as np
np.random.seed(123)

# %%
total_alunos = len(nomes)

# %%
total_alunos
# Out:
# 400

# %%
nomes["id_aluno"] = np.random.permutation(total_alunos) + 1

# %%
nomes.sample(3)
# Out:
#           nome  id_aluno
# 188    POLIANA       369
# 57      DAIANE       303
# 3    FRANCISCO       382

# %%
dominios = ['@dominiodoemail.com.br', '@servicodoemail.com']
nomes['dominio'] = np.random.choice(dominios, total_alunos)

# %%
nomes.sample(5)
# Out:
#           nome  id_aluno                 dominio
# 84    SEVERINO        78  @dominiodoemail.com.br
# 0         JOSE       331     @servicodoemail.com
# 179       IAGO       340  @dominiodoemail.com.br
# 10      SANDRA       174  @dominiodoemail.com.br
# 171  TERESINHA        45  @dominiodoemail.com.br

# %%
# como montar o email: chamei o nomes['email'] que seria o nome da coluna, chamei o nomes meu df .nome(minha coluna) .str(converti em string) .cat(catch pegar) (nomes.dominio)(concatenar os dois df) #str.lower(Para deixar tudo em minúsculo)
nomes['email'] = nomes.nome.str.cat(nomes.dominio).str.lower()

# %%
nomes.sample(5)
# Out:
#        nome  id_aluno                 dominio                         email
# 114  ARTHUR       320  @dominiodoemail.com.br  arthur@dominiodoemail.com.br
# 57   DAIANE       303     @servicodoemail.com     daiane@servicodoemail.com
# 85   HELENA       221  @dominiodoemail.com.br  helena@dominiodoemail.com.br
# 183   IRACI         8  @dominiodoemail.com.br   iraci@dominiodoemail.com.br
# 189   DALVA       137  @dominiodoemail.com.br   dalva@dominiodoemail.com.br

# %% [markdown]
# ## Criando a Tabela Curso

# %%
# !pip install html5lib
# !pip3 install lxml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import html5lib

# %%
url = 'http://tabela-cursos.herokuapp.com/'
pd.read_html(url)
## Site fora do ar
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-29-62c9c0d32f90> in <module>
#       1 url = 'http://tabela-cursos.herokuapp.com/'
# ----> 2 pd.read_html(url)
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1096     io = stringify_path(io)
#    1097
# -> 1098     return _parse(
#    1099         flavor=flavor,
#    1100         io=io,
#
# ...

# %%
nomes = pd.concat(frames)['nome'].to_frame() 
nomes.sample(5)

# %%
lista_curso = ['Lógica de Programação','Java para Web', 'Java para Web','Ruby on Rails','Cursos de Python','PHP com MySql']
lista_curso
# Out:
# ['Lógica de Programação',
#  'Java para Web',
#  'Java para Web',
#  'Ruby on Rails',
#  'Cursos de Python',
#  'PHP com MySql']

# %%
cursos = pd.DataFrame(lista_curso)
cursos.columns = ['Nome_do_Curso']
cursos.head()
# Out:
#            Nome_do_Curso
# 0  Lógica de Programação
# 1          Java para Web
# 2          Java para Web
# 3          Ruby on Rails
# 4       Cursos de Python

# %%
cursos['id'] = cursos.index+1

# %%
cursos.head()
# Out:
#            Nome_do_Curso  id
# 0  Lógica de Programação   1
# 1          Java para Web   2
# 2          Java para Web   3
# 3          Ruby on Rails   4
# 4       Cursos de Python   5

# %%
cursos.set_index('id')
# Out:
#             Nome_do_Curso
# id
# 1   Lógica de Programação
# 2           Java para Web
# 3           Java para Web
# 4           Ruby on Rails
# 5        Cursos de Python
# 6           PHP com MySql

# %%
cursos.head()
# Out:
#            Nome_do_Curso  id
# 0  Lógica de Programação   1
# 1          Java para Web   2
# 2          Java para Web   3
# 3          Ruby on Rails   4
# 4       Cursos de Python   5

# %% [markdown]
# ## MAtriculando os alunos nos cursos

# %%
nomes.sample(5)
# Out:
#          nome  id_aluno                 dominio  \
# 59     ISABEL        83  @dominiodoemail.com.br
# 172    REBECA       165     @servicodoemail.com
# 130    JUNIOR       184  @dominiodoemail.com.br
# 70    JOAQUIM       248     @servicodoemail.com
# 171  VALDEMIR         3  @dominiodoemail.com.br
#
#                               email
# 59     isabel@dominiodoemail.com.br
# 172       rebeca@servicodoemail.com
# 130    junior@dominiodoemail.com.br
# 70       joaquim@servicodoemail.com
# 171  valdemir@dominiodoemail.com.br

# %%
nomes['matriculas'] = np.ceil(np.random.exponential(size=total_alunos)*1.5).astype(int)

# %%
nomes.sample(4)
# Out:
#           nome  id_aluno                 dominio  \
# 168   CRISTIAN       398     @servicodoemail.com
# 102   MARILENE       149  @dominiodoemail.com.br
# 153     CLEIDE       368     @servicodoemail.com
# 3    FRANCISCO       382     @servicodoemail.com
#
#                               email  matrículas  matriculas
# 168     cristian@servicodoemail.com           1           2
# 102  marilene@dominiodoemail.com.br           2           3
# 153       cleide@servicodoemail.com           1           1
# 3      francisco@servicodoemail.com           1           1

# %%
nomes.matriculas.describe()
# Out:
# count    400.000000
# mean       1.980000
# std        1.337562
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        3.000000
# max        7.000000
# Name: matriculas, dtype: float64

# %%
import seaborn as sns

# %%
sns.distplot(nomes.matriculas)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
nomes.matriculas.value_counts()
# Out:
# 1    209
# 2     83
# 3     55
# 4     27
# 5     17
# 7      5
# 6      4
# Name: matriculas, dtype: int64

# %%
nomes.sample(5)
# Out:
#        nome  id_aluno                 dominio                         email  \
# 115  TALITA        94  @dominiodoemail.com.br  talita@dominiodoemail.com.br
# 151   JOSUE       393  @dominiodoemail.com.br   josue@dominiodoemail.com.br
# 100    JOEL       194  @dominiodoemail.com.br    joel@dominiodoemail.com.br
# 181    YURI       225     @servicodoemail.com       yuri@servicodoemail.com
# 83     EDNA       275  @dominiodoemail.com.br    edna@dominiodoemail.com.br
#
#      matriculas
# 115           1
# 151           5
# 100           3
# 181           2
# 83            1

# %% [markdown]
# ## Selecionando Cursos

# %%
nomes.sample(5)
# Out:
#          nome  id_aluno                 dominio                         email  \
# 103     KATIA       145     @servicodoemail.com      katia@servicodoemail.com
# 35      CARLA       262  @dominiodoemail.com.br   carla@dominiodoemail.com.br
# 168  CRISTIAN       398     @servicodoemail.com   cristian@servicodoemail.com
# 68       CAIO       283  @dominiodoemail.com.br    caio@dominiodoemail.com.br
# 191    TERESA       264  @dominiodoemail.com.br  teresa@dominiodoemail.com.br
#
#      matriculas
# 103           1
# 35            2
# 168           2
# 68            5
# 191           2

# %%
#preciso saber a qtd de matrículas de cada aluno
todas_matriculas = []
#um jeito pra calcular de maneira randomica os 20 cursos
x = np.random.rand(20)
prob = x / sum(x)

# %%
todas_matriculas = []
x = np.random.rand(6)
prob = x / sum(x)

# %%
for index, row in nomes.iterrows():
  id = row.id_aluno
  matriculas = row.matriculas
  for i in range(matriculas):
    mat = [id, np.random.choice(cursos.index, p = prob)]
    todas_matriculas.append(mat)



matriculas = pd.DataFrame(todas_matriculas, columns = ['id_aluno', 'id_curso'])
matriculas.head(5)
# Out:
#    id_aluno  id_curso
# 0       235         5
# 1       235         5
# 2        43         5
# 3       304         3
# 4       156         1

# %%
#quantos alunos tem inscritos em cada curso?
matriculas.groupby('id_curso').count().join(cursos['Nome_do_Curso']).rename(columns={'id_aluno':'quantidade_de_alunos'})
# Out:
#           quantidade_de_alunos          Nome_do_Curso
# id_curso
# 0                           57  Lógica de Programação
# 1                          183          Java para Web
# 2                          106          Java para Web
# 3                          203          Ruby on Rails
# 4                           69       Cursos de Python
# 5                          174          PHP com MySql

# %%
nomes.sample(5)
# Out:
#           nome  id_aluno                 dominio  \
# 8         LUIZ       208     @servicodoemail.com
# 31      JOSEFA       103     @servicodoemail.com
# 148  APARECIDO       332  @dominiodoemail.com.br
# 181    IRACEMA       168  @dominiodoemail.com.br
# 54       MARIO       164  @dominiodoemail.com.br
#
#                                email  matriculas
# 8            luiz@servicodoemail.com           2
# 31         josefa@servicodoemail.com           1
# 148  aparecido@dominiodoemail.com.br           1
# 181    iracema@dominiodoemail.com.br           1
# 54       mario@dominiodoemail.com.br           2

# %%
cursos.sample(5)
# Out:
#            Nome_do_Curso  id
# 3          Ruby on Rails   4
# 1          Java para Web   2
# 4       Cursos de Python   5
# 2          Java para Web   3
# 0  Lógica de Programação   1

# %%
matriculas.head(5)
# Out:
#    id_aluno  id_curso
# 0       235         5
# 1       235         5
# 2        43         5
# 3       304         3
# 4       156         1

# %%
matriculas_por_curso = matriculas.groupby('id_curso').count().join(cursos['Nome_do_Curso']).rename(columns={'id_aluno':'quantidade_de_alunos'})
matriculas_por_curso.head()
# Out:
#           quantidade_de_alunos          Nome_do_Curso
# id_curso
# 0                           57  Lógica de Programação
# 1                          183          Java para Web
# 2                          106          Java para Web
# 3                          203          Ruby on Rails
# 4                           69       Cursos de Python

# %% [markdown]
# ## Exportar quantidade de alunos por curso em CSV (Saída em diferentes formatos)

# %%
matriculas_por_curso.head()
# Out:
#           quantidade_de_alunos          Nome_do_Curso
# id_curso
# 0                           57  Lógica de Programação
# 1                          183          Java para Web
# 2                          106          Java para Web
# 3                          203          Ruby on Rails
# 4                           69       Cursos de Python

# %%
#exportar para css
matriculas_por_curso.to_csv('matriculas_por_curso.csv', index = False)

# %%
matriculas_json = matriculas_por_curso.to_json()

# %%
matriculas_json
# Out:
# '{"quantidade_de_alunos":{"0":57,"1":183,"2":106,"3":203,"4":69,"5":174},"Nome_do_Curso":{"0":"L\\u00f3gica de Programa\\u00e7\\u00e3o","1":"Java para Web","2":"Java para Web","3":"Ruby on Rails","4":"Cursos de Python","5":"PHP com MySql"}}'

# %%
matriculas_html = matriculas_por_curso.to_html()

# %%
matriculas_html
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>quantidade_de_alunos</th>\n      <th>Nome_do_Curso</th>\n    </tr>\n    <tr>\n      <th>id_curso</th>\n      <th></th>\n      <th></th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>57</td>\n      <td>Lógica de Programação</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>183</td>\n      <td>Java para Web</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>106</td>\n      <td>Java para Web</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>203</td>\n      <td>Ruby on Rails</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>69</td>\n      <td>Cursos de Python</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>174</td>\n      <td>PHP com MySql</td>\n    </tr>\n  </tbody>\n</table>'

# %% [markdown]
# ## SQL

# %%
from sqlalchemy import create_engine, MetaData, Table, inspect # adicionando o método inspect

engine = create_engine('sqlite:///:memory:')
engine
type(engine)

matriculas_por_curso.to_sql('matriculas', engine)

inspector = inspect(engine) # criando um Inspector object
print(inspector.get_table_names()) # Exibindo as tabelas com o inspecto
# Out:
# ['matriculas']
